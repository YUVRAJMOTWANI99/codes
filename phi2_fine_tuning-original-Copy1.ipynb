# %% [markdown]
# ### Downloading dependencies

# %%
# !pip install -U trl accelerate peft -i https://pypi.org/simple/ bitsandbytes transformers trl huggingface_hub
# %pip install -U datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple/
# Requirement already satisfied: trl in /home/jupyter-admin/.local/lib/python3.10/site-packages (0.8.6)
# Requirement already satisfied: accelerate in /home/jupyter-admin/.local/lib/python3.10/site-packages (0.30.0)
# Requirement already satisfied: peft in /home/jupyter-admin/.local/lib/python3.10/site-packages (0.10.0)
# Requirement already satisfied: bitsandbytes in /home/jupyter-admin/.local/lib/python3.10/site-packages (0.43.1)
# Requirement already satisfied: transformers in /home/jupyter-admin/.local/lib/python3.10/site-packages (4.40.2)
# Requirement already satisfied: huggingface_hub in /home/jupyter-admin/.local/lib/python3.10/site-packages (0.23.0)
# Requirement already satisfied: torch>=1.4.0 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from trl) (2.1.2)
# Requirement already satisfied: numpy>=1.18.2 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from trl) (1.26.4)
# Requirement already satisfied: datasets in /home/jupyter-admin/.local/lib/python3.10/site-packages (from trl) (2.19.1)
# Requirement already satisfied: tyro>=0.5.11 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from trl) (0.8.3)
# Requirement already satisfied: packaging>=20.0 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /opt/tljh/user/lib/python3.10/site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: pyyaml in /opt/tljh/user/lib/python3.10/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: safetensors>=0.3.1 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from accelerate) (0.4.2)
# Requirement already satisfied: tqdm in /home/jupyter-admin/.local/lib/python3.10/site-packages (from peft) (4.66.2)
# Requirement already satisfied: filelock in /home/jupyter-admin/.local/lib/python3.10/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /opt/tljh/user/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from huggingface_hub) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from huggingface_hub) (4.9.0)
# Requirement already satisfied: sympy in /home/jupyter-admin/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (1.12)
# Requirement already satisfied: networkx in /home/jupyter-admin/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/tljh/user/lib/python3.10/site-packages (from torch>=1.4.0->trl) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from torch>=1.4.0->trl) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4.0->trl) (12.4.127)
# Requirement already satisfied: docstring-parser>=0.14.1 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from tyro>=0.5.11->trl) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from tyro>=0.5.11->trl) (13.7.0)
# Requirement already satisfied: shtab>=1.5.6 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from tyro>=0.5.11->trl) (1.7.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets->trl) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets->trl) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets->trl) (0.3.8)
# Requirement already satisfied: pandas in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets->trl) (2.2.0)
# Requirement already satisfied: xxhash in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets->trl) (3.4.1)
# Requirement already satisfied: multiprocess in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets->trl) (0.70.16)
# Requirement already satisfied: aiohttp in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets->trl) (3.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from aiohttp->datasets->trl) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/tljh/user/lib/python3.10/site-packages (from aiohttp->datasets->trl) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from aiohttp->datasets->trl) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from aiohttp->datasets->trl) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from aiohttp->datasets->trl) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from aiohttp->datasets->trl) (4.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/tljh/user/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/tljh/user/lib/python3.10/site-packages (from jinja2->torch>=1.4.0->trl) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from pandas->datasets->trl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from pandas->datasets->trl) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from pandas->datasets->trl) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets->trl) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in /home/jupyter-admin/.local/lib/python3.10/site-packages (2.19.1)
# Requirement already satisfied: filelock in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets) (2.2.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/tljh/user/lib/python3.10/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets) (2024.2.0)
# Requirement already satisfied: aiohttp in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets) (0.23.0)
# Requirement already satisfied: packaging in /home/jupyter-admin/.local/lib/python3.10/site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/tljh/user/lib/python3.10/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/tljh/user/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from huggingface-hub>=0.21.2->datasets) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/jupyter-admin/.local/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Loading the Libraries

# %%
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
import bitsandbytes as bnb
import torch
import torch.nn as nn
import transformers
from datasets import Dataset
from peft import LoraConfig, PeftConfig
from trl import SFTTrainer
from transformers import (AutoModelForCausalLM,
                          AutoTokenizer,
                          BitsAndBytesConfig,
                          TrainingArguments,
                          pipeline,
                          logging)
from sklearn.metrics import (accuracy_score,
                             classification_report,
                             confusion_matrix)
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Loading the Data

# %%
# filename = "/kaggle/input/sentiment-analysis-for-financial-news/all-data.csv"
filename="ft_data.xlsx"

df = pd.read_excel(filename)
df.head()
# Out:
#           intent                                              query
# 0  Card: disable  Need to block my card ASAP, think it's been co...
# 1  Card: disable  Freeze my card, pretty sure I left it at the b...
# 2  Card: disable  Can you put a hold on my card? I can't find it...
# 3  Card: disable  Ugh, lost my wallet. Disable my card before so...
# 4  Card: disable  Hey, I think my card's been nicked! Lock it do...

# %% [markdown]
# ### Data Pre-Processing

# %%
X_train = list()
X_test = list()
for intent in df['intent'].unique():
    train, test  = train_test_split(df[df.intent==intent],
                                    train_size=0.4,test_size=0.3,
                                    random_state=42)
    X_train.append(train)
    X_test.append(test)

X_train[:1]
# Out:
# [           intent                                              query
#  11  Card: disable               I want to block my card immediately.
#  3   Card: disable  Ugh, lost my wallet. Disable my card before so...
#  18  Card: disable  Can you assist me in pausing my card transacti...
#  16  Card: disable   Put a hold on my card, I can't find it anywhere.
#  13  Card: disable            How do I go about deactivating my card?
#  2   Card: disable  Can you put a hold on my card? I can't find it...
#  9   Card: disable  Something's fishy with my card. Shut it down u...
#  19  Card: disable     Please deactivate my banking card temporarily.]

# %%
X_train = pd.concat(X_train).sample(frac=1, random_state=10)
X_test = pd.concat(X_test)
X_test
# Out:
#                                        intent  \
# 0                               Card: disable
# 17                              Card: disable
# 15                              Card: disable
# 1                               Card: disable
# 8                               Card: disable
# ..                                        ...
# 877  User Account: change password post login
# 875  User Account: change password post login
# 861  User Account: change password post login
# 868  User Account: change password post login
# 865  User Account: change password post login
#
#                                                  query
# 0    Need to block my card ASAP, think it's been co...
# 17   I need to block my card as I suspect it's been...
# 15   I lost my wallet, can you disable my card to p...
# 1    Freeze my card, pretty sure I left it at the b...
# 8                  Put my card on ice; it's gone AWOL.
# ..                                                 ...
# 877  What's the procedure to update my login passwo...
# 875  Show me steps to change my user account password.
# 861  Need to update my current password, what's the...
# 868          Change password feature? Where's that at?
# 865  My ex knows my password ðŸ¤¦, how do I change it?
#
# [264 rows x 2 columns]

# %% [markdown]
# ### Evaluation or Validation Data

# %%
eval_idx = [idx for idx in df.index if idx not in list(train.index) + list(test.index)]
eval_idx[:5]
X_eval = df[df.index.isin(eval_idx)]
X_eval[:5]
# Out:
#           intent                                              query
# 0  Card: disable  Need to block my card ASAP, think it's been co...
# 1  Card: disable  Freeze my card, pretty sure I left it at the b...
# 2  Card: disable  Can you put a hold on my card? I can't find it...
# 3  Card: disable  Ugh, lost my wallet. Disable my card before so...
# 4  Card: disable  Hey, I think my card's been nicked! Lock it do...

# %%
X_eval = (X_eval
          .groupby('intent', group_keys=False)
          .apply(lambda x: x.sample(n=50, random_state=10, replace=True)))
X_train = X_train.reset_index(drop=True)
# Out:
# /tmp/ipykernel_22039/2641210467.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(n=50, random_state=10, replace=True)))

# %% [markdown]
# ### loading the model

# %%
model_name = "mistralai/Mistral-7B-Instruct-v0.2"

compute_dtype = getattr(torch, "float16")

# Model Configurations
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=False,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
)

# Loading the Model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    trust_remote_code=True,
    device_map="auto",
    quantization_config=bnb_config,
)

model.config.use_cache = False
model.config.pretraining_tp = 1

# Loading the Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name,
                                          trust_remote_code=True,
                                         )
tokenizer.pad_token = tokenizer.eos_token
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
import json

with open('finetuning_data.jsonl', 'r') as json_file:
    json_list = list(json_file)
data=[]
for json_str in json_list:
    data.append(json.loads(json_str))
# print(data[322]["messages"][1]["content"])

# %% [markdown]
# ### Transform Data into LLM Training Form using Dataset Library

# %%
import pandas as pd
train=pd.DataFrame()

# %%
temp=[]
for i in range(len(data)):
   temp.append(f"""<Input> {data[i]['messages'][1]['content']} <Output> {data[i]['messages'][2]['content']}""")

train=pd.DataFrame(temp)

# %%
eval_=train[15:35]

# %%
train.rename(columns={'Unnamed: 0':'query'}, inplace=True )

# %% [markdown]
# #### The pipeline() function from the Hugging Face Transformers library is used to generate text from the language model. The task argument specifies that the task is text generation. The model and tokenizer arguments specify the pre-trained Phi-2 language model and the tokenizer for the language model. The max_new_tokens argument specifies the maximum number of new tokens to generate. The temperature argument controls the randomness of the generated text. A lower temperature will produce more predictable text, while a higher temperature will produce more creative and unexpected text.

# %%
def predict(X_test, model, tokenizer):
    y_pred = []
    for i in tqdm(range(len(X_test))):
        prompt = X_test.iloc[i]["query"]
        pipe = pipeline(task="text-generation",
                        model=model,
                        tokenizer=tokenizer,
                        max_new_tokens = 100, #keeping it large no. like 50 was producing unnecessary
                                            #text making it difficult to extract the intent, ON OTHER HAND 
                                            #keeping it small is unable to generate the intents which are bit longer
                        temperature = 0.0,
                       )
        result = pipe(prompt, pad_token_id=pipe.tokenizer.eos_token_id)
        answer = result[0]['generated_text'].lower()
        y_pred.append(answer)
    return y_pred

# %%
train.rename{0:"query"}
# Out:
#   Cell In[35], line 1
#     train.rename{0:"query"}
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Let's Fine Tune Now
# We configures and initializes a Simple Fine-tuning Trainer (SFTTrainer) for training a large language model using the Parameter-Efficient Fine-Tuning (PEFT) method.
# Which should save time as it operates on a reduced number of parameters compared to the model's overall size.
# The PEFT method focuses on refining a limited set of (additional) model parameters, while keeping the majority of the pre-trained LLM parameters fixed.
# This significantly reduces both computational and storage expenses. Additionally, this strategy addresses the challenge of catastrophic forgetting, which often occurs during the complete fine-tuning of LLMs.

# %%
peft_config = LoraConfig(
    r=16,
    lora_alpha=16,
    target_modules=[
    "q_proj",
    "up_proj",
    "o_proj",
    "k_proj",
    "down_proj",
    "gate_proj",
    "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
)
training_arguments = TrainingArguments(
    output_dir="logs",
    num_train_epochs=5,
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8, # 4
    optim="paged_adamw_32bit",
    save_steps=0,
    logging_steps=25,
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=True,
    bf16=False,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="cosine",
    report_to="tensorboard",
    evaluation_strategy="epoch"
)

trainer = SFTTrainer(
    model=model,
    train_dataset=train,
    # eval_dataset=eval_,
    peft_config=peft_config,
    dataset_text_field="query",
    tokenizer=tokenizer,
    args=training_arguments,
    packing=False,
    max_seq_length=512,
)

trainer.train()

# Save trained model
trainer.model.save_pretrained("mistral_conv_intent_sim-model")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_24017/4139483696.py in ?()
#      33     report_to="tensorboard",
#      34     evaluation_strategy="epoch"
#      35 )
#      36
# ---> 37 trainer = SFTTrainer(
#      38     model=model,
#      39     train_dataset=train,
#      40     # eval_dataset=eval_,
#
# ~/.local/lib/python3.10/site-packages/trl/trainer/sft_trainer.py in ?(self, model, args, data_collator, train_dataset, eval_dataset, tokenizer, model_init, compute_metrics, callbacks, optimizers, preprocess_logits_for_metrics, peft_config, dataset_text_field, packing, formatting_func, max_seq_length, infinite, num_of_sequences, chars_per_token, dataset_num_proc, dataset_batch_size, neftune_noise_alpha, model_init_kwargs, dataset_kwargs, eval_packing)
#     279         with PartialState().local_main_process_first():
#     280             if dataset_kwargs is None:
#     281                 dataset_kwargs = {}
#     282             if train_dataset is not None:
# --> 283                 train_dataset = self._prepare_dataset(
#     284                     train_dataset,
#     285                     tokenizer,
#     286                     packing,
#
# ~/.local/lib/python3.10/site-packages/trl/trainer/sft_trainer.py in ?(self, dataset, tokenizer, packing, dataset_text_field, max_seq_length, formatting_func, num_of_sequences, chars_per_token, remove_unused_columns, append_concat_token, add_special_tokens, skip_prepare_dataset)
#     420         ) and not isinstance(dataset, datasets.IterableDataset):
#     421             return dataset
#     422
#     423         if not packing:
# --> 424             return self._prepare_non_packed_dataloader(
#     425                 tokenizer,
#     426                 dataset,
#     427                 dataset_text_field,
#
# ~/.local/lib/python3.10/site-packages/trl/trainer/sft_trainer.py in ?(self, tokenizer, dataset, dataset_text_field, max_seq_length, formatting_func, add_special_tokens, remove_unused_columns)
#     480             return {"input_ids": outputs["input_ids"], "attention_mask": outputs["attention_mask"]}
#     481
#     482         signature_columns = ["input_ids", "labels", "attention_mask"]
#     483
# --> 484         extra_columns = list(set(dataset.column_names) - set(signature_columns))
#     485
#     486         if not remove_unused_columns and len(extra_columns) > 0:
#     487             warnings.warn(
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column_names'

# %% [markdown]
# ### Predicting the intents for test data

# %%
y_pred = predict(X_test, model, tokenizer)
# Out:
#   0%|          | 0/264 [00:00<?, ?it/s]/home/jupyter-admin/.local/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# 100%|██████████| 264/264 [01:47<00:00,  2.46it/s]

# %% [markdown]
# ### Accuracy

# %%
y_true_list=list(y_true)

# %%
count=0
i=0
for i in range(0,len(y_pred)):
    if y_pred[i].split('is')[-1].strip()==y_true_list[i].lower():
        count+=1
    i+=1
print(count*100/len(y_pred))
# Out:
# 8.712121212121213

# %% [markdown]
# ### Outcomes
# 1. when no. of epoch were 2 accuracy was 3.57% , for 5 epoch it is 8.7%.
# 2. Need to extract the intent efficiently from the output after increasing max_new_token.
