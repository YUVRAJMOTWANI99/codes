# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Join Discord if you need help + support us if you can!
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://github.com/unslothai/unsloth#installation-instructions---conda).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save) (eg for Llama.cpp).

# %%
# %%capture
# Installs Unsloth, Xformers (Flash Attention) and all other packages!
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "xformers<0.0.26" trl peft accelerate bitsandbytes

# %% [markdown]
# * We support Llama, Mistral, CodeLlama, TinyLlama, Vicuna, Open Hermes etc
# * And Yi, Qwen ([llamafied](https://huggingface.co/models?sort=trending&search=qwen+llama)), Deepseek, all Llama, Mistral derived archs.
# * We support 16bit LoRA or 4bit QLoRA. Both 2x faster.
# * `max_seq_length` can be set to anything, since we do automatic RoPE Scaling via [kaiokendev's](https://kaiokendev.github.io/til) method.
# * With [PR 26037](https://github.com/huggingface/transformers/pull/26037), we support downloading 4bit models **4x faster**! [Our repo](https://huggingface.co/unsloth) has Llama, Mistral 4bit models.
# * [**NEW**] We make Gemma 6 trillion tokens **2.5x faster**! See our [Gemma notebook](https://colab.research.google.com/drive/10NbwlsRChbma1v55m8LAPYG15uQv6HLo?usp=sharing)

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/mistral-7b-bnb-4bit",
    "unsloth/mistral-7b-instruct-v0.2-bnb-4bit",
    "unsloth/llama-2-7b-bnb-4bit",
    "unsloth/llama-2-13b-bnb-4bit",
    "unsloth/codellama-34b-bnb-4bit",
    "unsloth/tinyllama-bnb-4bit",
    "unsloth/gemma-7b-bnb-4bit", # New Google 6 trillion tokens model 2.5x faster!
    "unsloth/gemma-2b-bnb-4bit",
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/mistral-7b-bnb-4bit", # Choose ANY! eg teknium/OpenHermes-2.5-Mistral-7B
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Mistral patching release 2024.5
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.2.1+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. Xformers = 0.0.25.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unused kwargs: ['quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# model.safetensors:   0%|          | 0.00/4.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/971 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2024.5 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the Alpaca dataset from [yahma](https://huggingface.co/datasets/yahma/alpaca-cleaned), which is a filtered version of 52K of the original [Alpaca dataset](https://crfm.stanford.edu/2023/03/13/alpaca.html). You can replace this code section with your own data prep.
#
# **[NOTE]** To train only on completions (ignoring the user's input) read TRL's docs [here](https://huggingface.co/docs/trl/sft_trainer#train-on-completions-only).
#
# **[NOTE]** Remember to add the **EOS_TOKEN** to the tokenized output!! Otherwise you'll get infinite generations!
#
# If you want to use the `ChatML` template for ShareGPT datasets, try our conversational [notebook](https://colab.research.google.com/drive/1Aau3lgPzeZKQ-98h69CCu1UJcvIBLmy2?usp=sharing).
#
# For text completions like novel writing, try this [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing).

# %%
# alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

# ### Instruction:
# {}

# ### Input:
# {}

# ### Response:
# {}"""


# EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
# def formatting_prompts_func(examples):
#     instructions = examples["instruction"]
#     inputs       = examples["input"]
#     outputs      = examples["output"]
#     texts = []
#     for instruction, input, output in zip(instructions, inputs, outputs):
#         # Must add EOS_TOKEN, otherwise your generation will go on forever!
#         text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN
#         texts.append(text)
#     return { "text" : texts, }
# pass

# from datasets import load_dataset
# dataset = load_dataset("yahma/alpaca-cleaned", split = "train")
# dataset = dataset.map(formatting_prompts_func, batched = True,)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from datasets import Dataset
filename="/content/ft_data.xlsx"

df = pd.read_excel(filename)
X_train = list()
X_test = list()
for intent in df['intent'].unique():
    train, test  = train_test_split(df[df.intent==intent],
                                    train_size=0.4,test_size=0.1,
                                    random_state=42)
    X_train.append(train)
    X_test.append(test)
X_train = pd.concat(X_train).sample(frac=1, random_state=10)
X_test = pd.concat(X_test)
eval_idx = [idx for idx in df.index if idx not in list(train.index) + list(test.index)]

X_eval = df[df.index.isin(eval_idx)]
X_eval = (X_eval
          .groupby('intent', group_keys=False)
          .apply(lambda x: x.sample(n=50, random_state=10, replace=True)))
X_train = X_train.reset_index(drop=True)

# %%
def generate_prompt(data_point):
    return f"""The intent of the following query: '{data_point["query"]}' is {data_point["intent"]}""".strip()

def generate_test_prompt(data_point):
    return f"""The intent of the following query: '{data_point["query"]}' is""".strip()

# %%
X_train = pd.DataFrame(X_train.apply(generate_prompt, axis=1),
                       columns=["query"])

# %%
y_true = X_test.intent
X_test = pd.DataFrame(X_test.apply(generate_test_prompt, axis=1), columns=["query"])

train_data = Dataset.from_pandas(X_train)
eval_data = Dataset.from_pandas(X_eval)

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!

# %%
from trl import SFTTrainer
from transformers import TrainingArguments

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = train_data,
    eval_dataset=eval_data,
    dataset_text_field = "query",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        max_steps = 60, # Set num_train_epochs = 1 for full training runs
        learning_rate = 2e-4,
        fp16 = not torch.cuda.is_bf16_supported(),
        bf16 = torch.cuda.is_bf16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
    ),
)

model.save_pretrained("lora_model") # Local saving
tokenizer.save_pretrained("lora_model")
# Out:
# /usr/local/lib/python3.10/dist-packages/multiprocess/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Map (num_proc=2):   0%|          | 0/352 [00:00<?, ? examples/s]
# Map (num_proc=2):   0%|          | 0/2200 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/tokenizer.model',
#  'lora_model/added_tokens.json',
#  'lora_model/tokenizer.json')

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 352 | Num Epochs = 2
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 60
#  "-____-"     Number of trainable parameters = 41,943,040
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 02:58, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.016200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.971600</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.960700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.440800</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.943900</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.550900</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.081400</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.947300</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.938500</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.788600</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.631200</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.420900</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.528800</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.514000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.389400</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.301800</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.304600</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.332600</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.331000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.158100</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.199000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.127700</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.116800</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.140800</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.011700</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.134300</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.113400</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.161800</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.142500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.979700</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.995000</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.133500</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.993300</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.930600</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.105400</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.931500</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.935200</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.880200</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.988300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.953200</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.938600</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.923900</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.756800</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.903600</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.780000</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.910100</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.829900</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.682200</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.727400</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.677100</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.706200</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.666100</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.786400</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.872300</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.669600</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.794400</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.630600</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.740900</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.710000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.780800</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
#@title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-21a4da9893ae> in <cell line: 3>()
#       1 #@title Show final memory and time stats
#       2 used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
# ----> 3 used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
#       4 used_percentage = round(used_memory         /max_memory*100, 3)
#       5 lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
#
# NameError: name 'start_gpu_memory' is not defined

# %%
X_test
# Out:
#                                                  query
# 0    The intent of the following query: 'Need to bl...
# 17   The intent of the following query: 'I need to ...
# 20   The intent of the following query: 'Hey, can y...
# 37   The intent of the following query: 'I need ass...
# 40   The intent of the following query: 'Any clue w...
# ..                                                 ...
# 837  The intent of the following query: 'I need to ...
# 840  The intent of the following query: 'Yo, can I ...
# 857  The intent of the following query: 'My card do...
# 860  The intent of the following query: 'Yo, how do...
# 877  The intent of the following query: 'What's the...
#
# [88 rows x 1 columns]

# %%
X_test_list=list(X_test['query'])

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the instruction and input - leave the output blank!

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
ans=[]
for i in range(len(X_test)):
  inputs = tokenizer(
  [
      X_test_list[i]
  ], return_tensors = "pt").to("cuda")

  outputs = model.generate(**inputs, max_new_tokens = 12, use_cache = True)
  ans.append(tokenizer.batch_decode(outputs))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.

# %%
# !pip install langchain langchain_openai
# Out:
# Collecting langchain
#   Downloading langchain-0.1.20-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 7.5 MB/s eta 0:00:00
# Collecting langchain_openai
#   Downloading langchain_openai-0.1.6-py3-none-any.whl (34 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.6-py3-none-any.whl (28 kB)
# Collecting langchain-community<0.1,>=0.0.38 (from langchain)
#   Downloading langchain_community-0.0.38-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 20.6 MB/s eta 0:00:00
# Collecting langchain-core<0.2.0,>=0.1.52 (from langchain)
#   Downloading langchain_core-0.1.52-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.9/302.9 kB 22.0 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain)
#   Downloading langchain_text_splitters-0.0.1-py3-none-any.whl (21 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.57-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.0/121.0 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.3.0)
# Collecting openai<2.0.0,>=1.24.0 (from langchain_openai)
#   Downloading openai-1.28.1-py3-none-any.whl (320 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.1/320.1 kB 28.8 MB/s eta 0:00:00
# Collecting tiktoken<1,>=0.5.2 (from langchain_openai)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.21.2-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 6.9 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.2.0,>=0.1.52->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.52->langchain)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 8.1 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai<2.0.0,>=1.24.0->langchain_openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.24.0->langchain_openai) (4.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.5.2->langchain_openai) (2023.12.25)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.24.0->langchain_openai) (1.2.1)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain_openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 10.8 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain_openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.3 MB/s eta 0:00:00
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.52->langchain)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: packaging, orjson, mypy-extensions, jsonpointer, h11, typing-inspect, tiktoken, marshmallow, jsonpatch, httpcore, langsmith, httpx, dataclasses-json, openai, langchain-core, langchain-text-splitters, langchain_openai, langchain-community, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed dataclasses-json-0.6.6 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 jsonpatch-1.33 jsonpointer-2.4 langchain-0.1.20 langchain-community-0.0.38 langchain-core-0.1.52 langchain-text-splitters-0.0.1 langchain_openai-0.1.6 langsmith-0.1.57 marshmallow-3.21.2 mypy-extensions-1.0.0 openai-1.28.1 orjson-3.10.3 packaging-23.2 tiktoken-0.6.0 typing-inspect-0.9.0

# %%
ans
# Out:
# [["<s> The intent of the following query: 'Need to block my card ASAP, think it's been compromised.' is Card: disable temporary disable close block shut off end terminate"],
#  ["<s> The intent of the following query: 'I need to block my card as I suspect it's been stolen.' is Card: disable temporarily or permanently close account close card disable card"],
#  ["<s> The intent of the following query: 'Hey, can you turn my card back on?' is Card: enable status post disablement</s>"],
#  ["<s> The intent of the following query: 'I need assistance enabling my card after a temporary hold.' is Card: enable after temporary hold status</s>"],
#  ["<s> The intent of the following query: 'Any clue where my new card's at in the mail?' is Card: get shipping status where is it?'s where'"],
#  ["<s> The intent of the following query: 'Has my prepaid debit card been sent out yet? I'd like to track it.' is Card: get shipping status where is it? post mail delivery"],
#  ["<s> The intent of the following query: 'Hey, I can't find my card anywhere, think it's gone for good.' is Card: report lost or stolen, where's my replacement"],
#  ["<s> The intent of the following query: 'I need to report a lost card, what are the steps?' is Card: report lost or stolen report stolen or lost card report"],
#  ["<s> The intent of the following query: 'How much do I have in my account right now?' is Global: get balance statement view programmatic request get balance statement"],
#  ["<s> The intent of the following query: 'I'd like to see my current balance, can you fetch that for me?' is Global: get balance statement view programmatic request get balance statement"],
#  ["<s> The intent of the following query: 'Yo, what's my routing number for direct deposits?' is Global: get routing number direct deposit info view routing"],
#  ["<s> The intent of the following query: 'Please tell me my account's routing number for direct deposit.' is Global: get routing number direct deposit info view routing"],
#  ["<s> The intent of the following query: 'Can I take a peek at my latest card statement?' is Statement: get latest history view statement view history get statement view"],
#  ["<s> The intent of the following query: 'Tell me how to access my card's transaction history statement.' is Statement: get history view transactions list statement history get info view"],
#  ["<s> The intent of the following query: 'Can you show me the list of my recent spending?' is Spending Tracker: get info view spending tracker history"],
#  ["<s> The intent of the following query: 'Where can I find the history of my deposits and withdrawals?' is Statement: get history view transactions deposits withdrawals spend account"],
#  ["<s> The intent of the following query: 'Hey, just noticed a charge I don't recognize. Can you help?' is Transaction: report dispute incorrect charge unauthorized purchase alert spam"],
#  ["<s> The intent of the following query: 'How can I get assistance with a transaction that I didn't make?' is Transaction: report fraudulent activity or dispute charge incorrectly applied"],
#  ["<s> The intent of the following query: 'I need to swap my email, what's the process?' is User Account: change email address post login post sign up post"],
#  ["<s> The intent of the following query: 'My primary email has changed, how do I reflect this in my banking details?' is User Account: change email address on file post login get info"],
#  ["<s> The intent of the following query: 'Need to update my home address, how do I do it?' is User Account: change mailing address postal code profile edit"],
#  ["<s> The intent of the following query: 'How to edit my mailing address on the banking app?' is User Account: change mailing address postal mail opt in"],
#  ["<s> The intent of the following query: 'How do I send money from my spend account to another bank?' is Spend Account: transfer funds external bank account connect transfer funds"],
#  ["<s> The intent of the following query: 'Tell me how to initiate a fund transfer from my spending account, please.' is Spend Account: transfer funds external bank account initiation post"],
#  ["<s> The intent of the following query: 'How do I send a check from my account?' is Spend Account: transfer funds checks spend account: transfer funds"],
#  ["<s> The intent of the following query: 'What are the instructions for sending a check from my spending account?' is Spend Account: transfer funds checks spend account funds checks spend"],
#  ["<s> The intent of the following query: 'How do I send money to my other bank account?' is Spend Account: transfer funds external bank account connect transfer funds"],
#  ["<s> The intent of the following query: 'Is it possible to transfer my funds to another financial institution?' is Spend Account: transfer funds external bank account connect feature opt"],
#  ["<s> The intent of the following query: 'Can you show me the deets of my savings program?' is Savings Account: get info view program profile get info view"],
#  ["<s> The intent of the following query: 'What incentives come with my current savings account?' is Savings Account: get info view program offers rewards incentives"],
#  ["<s> The intent of the following query: 'How do I link my other bank accounts to this one?' is User Account: connect banks accounts feature: connect banks feature add"],
#  ["<s> The intent of the following query: 'I need assistance with linking my additional bank accounts to this service.' is User Account: connect banks accounts post login sign up flow step"],
#  ["<s> The intent of the following query: 'Show me the perks for using my card' is Rewards: view offers and deals program info get info"],
#  ["<s> The intent of the following query: 'What are the special offers for this month in the rewards section?' is Rewards: view offers and deals view offers and deals"],
#  ["<s> The intent of the following query: 'Sign me up for those sweet reward perks, please!' is Rewards: opt in program sign up post login</s>"],
#  ["<s> The intent of the following query: 'How can I opt in for the cashback rewards?' is Rewards: opt in for program enrollment rewards offers"],
#  ["<s> The intent of the following query: 'I'm not feeling these rewards programs, how can I ditch it?' is Rewards: opt out of program enrollment</s>"],
#  ["<s> The intent of the following query: 'I'm not interested in the loyalty program anymore, how do I opt out?' is Rewards: opt out of program enrollment</s>"],
#  ["<s> The intent of the following query: 'How do I chat with a support agent?' is User Account: get help contact customer service center get help contact"],
#  ["<s> The intent of the following query: 'What are the customer service hours for banking support?' is Customer Account: get help contact customer service center get help contact"],
#  ["<s> The intent of the following query: 'How do I check out my spending habits on this app?' is Spending Tracker: get info view programmatic access get"],
#  ["<s> The intent of the following query: 'Please provide me the details of my spending tracker.' is Spending Tracker: get info view programmatic access get"],
#  ["<s> The intent of the following query: 'I don't want to overdraw my account anymore, how can I turn that off?' is Overdraft: opt out program enrollment: decline enrollment"],
#  ["<s> The intent of the following query: 'I need to deactivate the overdraft option, can you assist?' is Overdraft: opt out program enroll request cancel</s>"],
#  ["<s> The intent of the following query: 'How do I check my secure messages?' is User Account: get secure inbox messages secure inbox:"],
#  ["<s> The intent of the following query: 'Tell me how to open my secure inbox on the mobile app.' is User Account: get secure inbox messages view secure inbox"],
#  ["<s> The intent of the following query: 'Yo, what's the damage for using my card?' is Statement: get fee plan info view program fee plan info get"],
#  ["<s> The intent of the following query: 'What are the usage charges on different types of transactions for my card?' is Transaction: get fee plan info view program costs get fee plan"],
#  ["<s> The intent of the following query: 'I wanna add another card to my account, how do I do that?' is Card: add new card to account profile post login user account"],
#  ["<s> The intent of the following query: 'I'd like to add another card; do I do it through the app?' is Card: add new card to account profile post login user account"],
#  ["<s> The intent of the following query: 'How do I upload my ID for verification?' is Document: upload identity verification document proof of ID upload document upload"],
#  ["<s> The intent of the following query: 'What formats do you accept for uploading verification documents?' is Document: upload verification documents request start process step 1 of"],
#  ["<s> The intent of the following query: 'Where's the nearest ATM I can use?' is Spend Account: find ATMs and cash withdrawal and re"],
#  ["<s> The intent of the following query: 'I want to withdraw cash, where's the nearest spend account compatible ATM?' is Spend Account: get cash withdrawal and reload locations</s>"],
#  ["<s> The intent of the following query: 'Need to find a spot to reload my card, any ideas?' is Spend Account: get cash withdrawal and reload locations near"],
#  ["<s> The intent of the following query: 'Need to top up my card, what are the nearby reload options?' is Spend Account: get cash withdrawal and reload locations."],
#  ["<s> The intent of the following query: 'Gotta sign off, how do I log out of here?' is User Account: log out sign out sign out of my account"],
#  ["<s> The intent of the following query: 'Guide me through the process of logging out.' is User Account: log out sign out sign out user account log"],
#  ["<s> The intent of the following query: 'Hey, can you check if my card's been activated yet?' is Card: get info status where is it at activate? view"],
#  ["<s> The intent of the following query: 'Please provide the status update for my prepaid card.' is Card: get info status where is it at? get info"],
#  ["<s> The intent of the following query: 'How do I use e-signature for my docs?' is User Account: esign documents consent to terms and conditions es"],
#  ["<s> The intent of the following query: 'I want to e-sign a document, please assist.' is User Account: esign documents consent form esignature upload"],
#  ["<s> The intent of the following query: 'How do I refer a buddy to get that sweet referral bonus?' is Refer a Friend: get info view program sign up refer friend"],
#  ["<s> The intent of the following query: 'Can you give me details on the refer a friend bonus?' is Refer a Friend: get info view program offers rewards points refer"],
#  ["<s> The intent of the following query: 'Need to update my contact number, what's the process?' is User Account: change phone number post login post auth phone number"],
#  ["<s> The intent of the following query: 'How do I go about changing the registered phone number that I use for two-factor authentication?' is User Account: change phone number for two-factor authentication sign"],
#  ["<s> The intent of the following query: 'How do I change the name on my account profile?' is User Account: edit profile name post login get info profile name"],
#  ["<s> The intent of the following query: 'Tell me how to go about updating my name on my personal account.' is User Account: edit profile name post login</s>"],
#  ["<s> The intent of the following query: 'Hey, how do I change my card PIN?' is Card: reset PIN post login auth required</s>"],
#  ["<s> The intent of the following query: 'Please guide me through resetting my credit card PIN.' is Card: reset PIN post login auth required</s>"],
#  ["<s> The intent of the following query: 'I've decided to ditch my card, how do I kill it off?' is Card: cancel close account request post login auth required step "],
#  ["<s> The intent of the following query: 'I'm not using my prepaid card anymore, how do I close it?' is Card: cancel close account request post login auth required prepaid"],
#  ["<s> The intent of the following query: 'Hey, can I get a temp limit bump on my card for this vacay?' is Card: temporary limit increase request post login auth</s>"],
#  ["<s> The intent of the following query: 'For holiday shopping, I need a higher card limit, what should I do?' is Card: temporary limit increase request post login auth</s>"],
#  ["<s> The intent of the following query: 'How do I set up direct deposit for my paycheck?' is Spend Account: consent to direct deposit enrollment hook up"],
#  ["<s> The intent of the following query: 'I'm ready to set up direct deposit. Where should I begin?' is Spend Account: consent to direct deposit enrollment hook up"],
#  ["<s> The intent of the following query: 'How do I go about closing my account for good?' is User Account: closure request post login: submit request</s>"],
#  ["<s> The intent of the following query: 'Please provide steps to close my account with your bank.' is User Account: closure request post login: submit request</s>"],
#  ["<s> The intent of the following query: 'How do I tweak the alerts I'm getting from you guys?' is Notifications: manage alerts settings sign up for alerts"],
#  ["<s> The intent of the following query: 'Can I set specific alerts for deposits only?' is Notifications: sign up for alerts on deposits and"],
#  ["<s> The intent of the following query: 'How do I turn on notifications for my account?' is Notifications: sign up for alerts and notifications."],
#  ["<s> The intent of the following query: 'Can you set up text message notifications for my spending activity?' is Notifications: sign up for text alerts for my account"],
#  ["<s> The intent of the following query: 'Hey, it's been a while and my card still hasn't shown up. What do I do?' is Card: report not received yet, where is it? post"],
#  ["<s> The intent of the following query: 'I need to report a missing card shipment, it's overdue.' is Card: report not received shipment status missing or stolen card"],
#  ["<s> The intent of the following query: 'Yo, can I upgrade my card to something with more perks?' is Card: upgrade plan features program sign up request post login get"],
#  ["<s> The intent of the following query: 'My card doesn't tap to pay, can I upgrade it to one that does?' is Card: upgrade to tap to pay capability</s>"],
#  ["<s> The intent of the following query: 'Yo, how do I swap my password after I've logged in?' is User Account: change password post login post authn post auth"],
#  ["<s> The intent of the following query: 'What's the procedure to update my login password on the app?' is User Account: change password post login post log in post login"]]

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-3.5-turbo-0125", temperature=0, api_key="")
final=[]
for i in range(len(ans)):
  messages = [
      ("system", """You will be given the string, just return intent from it which is present in the following list and nothing else.
    Card: disable
    Card: enable
    Card: get shipping status where is
    Card: report stolen or lost
    Global: get balance
    Global: get routing number direct deposit info
    Statement: get
    Transaction: history
    Transaction: report dispute incorrect
    User Account: change email address
    User Account: change mailing address
    Spend Account: transfer funds
    Spend Account: transfer funds checks
    Spend Account: transfer funds external bank
    Savings Account: get info view program
    User Account: connect banks
    Rewards: view offers
    Rewards: opt in
    Rewards: opt out
    User Account: get help contact customer service',
    Spending Tracker: get info',
    Overdraft: opt out
    User Account: get secure inbox messages
    User Account: get fee plan info
    Card: add new
    Document: upload
    Spend Account: find ATMs
    Spend Account: get cash withdrawal and reload locations',
    User Account: log out
    Card: get info status
    User Account: esign
    Refer a Friend: get info
    User Account: change phone number
    User Account: edit profile name
    Card: reset PIN
    Card: cancel close
    Card: temporary limit increase
    Spend Account: consent to direct deposit',
    User Account: closure request
    Notifications: manage
    Notifications: sign up for
    Card: report not receiveda
    Card: replace or upgrade
    User Account: change password post login
  """),
      ("human", f"return the intent present in following phrase.{ans[i][0]}."),
  ]
  final.append(llm.invoke(messages))

# %%
ff_ans=[]
for i in range(len(final)):
  ff_ans.append(final[i].content)

# %%
y_true_list=list(y_true)

# %%
count=0
for i in range(len(ff_ans)):
  if ff_ans[i]==y_true_list[i]:
    count+=1
print(count*100/len(ff_ans))
# Out:
# 89.77272727272727
